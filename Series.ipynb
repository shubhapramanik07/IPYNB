# %%
import numpy as np
import pandas as pd

# %%
labels = ['a', 'b', 'c']
my_list = [1,24,5,3]
arr = np.array([2,3,14])
d = {1:33,2:89,3:10}

# %%
pd.Series(my_list)
# Out:
# 0     1
# 1    24
# 2     5
# 3     3
# dtype: int64

# %%
pd.Series(data = arr, index = labels)
# this assigns custom index to the series
# Out:
# a     2
# b     3
# c    14
# dtype: int64
