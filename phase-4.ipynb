# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
array1  = np.array([[1, 2, 3], [4, 5, 6]])
array2 = np.random.rand(3,3)
array3 = np.zeros((4,4))

# this way we can save it into flat file/ dataset
np.save("array1.npy", array1)
np.save('array2.npy', array2)
np.save('array3.npy', array3)

# %%
loaded_array1 = np.load("array1.npy")
print(loaded_array1)
# Out:
# [[1 2 3]
#  [4 5 6]]
# [[0.91396672 0.00494355 0.4859447 ]
#  [0.43891814 0.31518275 0.02506481]
#  [0.59914877 0.11365279 0.00335269]]

# %%
try:
    logo = np.load("numpy-logo.npy")
    
    # display the logo using matplotlib
    plt.figure(figsize=(10,5))
    plt.subplot(111)
    plt.imshow(logo)
    plt.axis('off')
    plt.title("NumPy Logo")
    plt.grid(False)

    # dark_logo = logo.copy()
    # dark_logo[dark_logo < 128] = 0
    # dark_logo[dark_logo >= 128] = 255
    # plt.figure(figsize=(10,5))
    # plt.subplot(111)
    # plt.imshow(dark_logo)
    # plt.axis('off')
    # plt.title("Dark NumPy Logo")
    # plt.grid(False)

    darked_logo = 1 - logo / 255.0
    plt.figure(figsize=(10,5))
    plt.subplot(111)
    plt.imshow(darked_logo)
    plt.axis('off')
    plt.title("Darkened NumPy Logo")
    plt.grid(False)



except FileNotFoundError:
    print("numpy-logo.npy file not found. Please ensure the file is in the correct directory.")
